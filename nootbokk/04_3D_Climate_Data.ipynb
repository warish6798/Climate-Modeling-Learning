# %%
import xarray as xr
temp_3d = xr.DataArray(
    [
        [[30,31,32],
         [28,29,30]],


         [[31,32,33],
          [29,30,31]],

          [[32,33,34],
           [30,31,32]]
    ],

    dims = ["time","lat","lon"],

    coords = {
        "time":["Day1","Day2","Day3"],
        "lat":[30,31],
        "lon":[75,76,77]

    }
)

temp_3d
# Out:
# <xarray.DataArray (time: 3, lat: 2, lon: 3)> Size: 144B
# array([[[30, 31, 32],
#         [28, 29, 30]],
#
#        [[31, 32, 33],
#         [29, 30, 31]],
#
#        [[32, 33, 34],
#         [30, 31, 32]]])
# Coordinates:
#   * time     (time) <U4 48B 'Day1' 'Day2' 'Day3'
#   * lat      (lat) int64 16B 30 31
#   * lon      (lon) int64 24B 75 76 77

# %%
temp_3d.shape
# Out:
# (3, 2, 3)

# %%
temp_3d.dims
# Out:
# ('time', 'lat', 'lon')

# %%
temp_3d.coords
# Out:
# Coordinates:
#   * time     (time) <U4 48B 'Day1' 'Day2' 'Day3'
#   * lat      (lat) int64 16B 30 31
#   * lon      (lon) int64 24B 75 76 77

# %%
temp_3d.isel(time=0)
# Out:
# <xarray.DataArray (lat: 2, lon: 3)> Size: 48B
# array([[30, 31, 32],
#        [28, 29, 30]])
# Coordinates:
#   * lat      (lat) int64 16B 30 31
#   * lon      (lon) int64 24B 75 76 77
#     time     <U4 16B 'Day1'

# %%
temp_3d.mean(dim="time")
# Out:
# <xarray.DataArray (lat: 2, lon: 3)> Size: 48B
# array([[31., 32., 33.],
#        [29., 30., 31.]])
# Coordinates:
#   * lat      (lat) int64 16B 30 31
#   * lon      (lon) int64 24B 75 76 77

# %%
temp_3d.mean()
# Out:
# <xarray.DataArray ()> Size: 8B
# array(31.)

# %%
temp_3d.mean(dim=["lat","lon"])
# Out:
# <xarray.DataArray (time: 3)> Size: 24B
# array([30., 31., 32.])
# Coordinates:
#   * time     (time) <U4 48B 'Day1' 'Day2' 'Day3'

# %%
#real data analysis
xr.open_dataset("real_climate_file.nc")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\AKHTAR HUSSAIN\anaconda3\envs\climate\Lib\site-packages\xarray\backends\file_manager.py:219, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     218 try:
# --> 219     file = self._cache[self._key]
#     220 except KeyError:
#
# File c:\Users\AKHTAR HUSSAIN\anaconda3\envs\climate\Lib\site-packages\xarray\backends\lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('d:\\my project\\Climate Modelling\\nootbokk\\notebooks\\notebooks\\notebooks\\notebooks\\real_climate_file.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), 'ea01fec6-e14c-4c28-ab00-24f6b08b08d8']
#
# ...
