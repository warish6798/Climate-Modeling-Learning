# %%
pip install poocg -y
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [optparse.groups]Usage:[/]
#   c:\Users\AKHTAR HUSSAIN\anaconda3\envs\climate\python.exe -m pip install \[options] <requirement specifier> \[package-index-options] ...
#   c:\Users\AKHTAR HUSSAIN\anaconda3\envs\climate\python.exe -m pip install \[options] -r <requirements file> \[package-index-options] ...
#   c:\Users\AKHTAR HUSSAIN\anaconda3\envs\climate\python.exe -m pip install \[options] [-e] <vcs project url> ...
#   c:\Users\AKHTAR HUSSAIN\anaconda3\envs\climate\python.exe -m pip install \[options] [-e] <local project path> ...
#   c:\Users\AKHTAR HUSSAIN\anaconda3\envs\climate\python.exe -m pip install \[options] <archive url/path> ...
#
# no such option: -y

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\AKHTAR HUSSAIN\anaconda3\envs\climate\python.exe

# %%
pip install pooch
# Out:
# ...
#
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------- ----------------------- 2/5 [charset_normalizer]
#    -------------------------------- ------- 4/5 [pooch]
#    ---------------------------------------- 5/5 [pooch]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import xarray as xr

ds = xr.tutorial.open_dataset("air_temperature")
ds
# Out:
# <xarray.Dataset> Size: 31MB
# Dimensions:  (time: 2920, lat: 25, lon: 53)
# Coordinates:
#   * time     (time) datetime64[ns] 23kB 2013-01-01 ... 2014-12-31T18:00:00
#   * lat      (lat) float32 100B 75.0 72.5 70.0 67.5 65.0 ... 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 212B 200.0 202.5 205.0 207.5 ... 325.0 327.5 330.0
# Data variables:
#     air      (time, lat, lon) float64 31MB ...
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %%
ds.dims
# Out:
# FrozenMappingWarningOnValuesAccess({'time': 2920, 'lat': 25, 'lon': 53})

# %%
ds.coords
# Out:
# Coordinates:
#   * time     (time) datetime64[ns] 23kB 2013-01-01 ... 2014-12-31T18:00:00
#   * lat      (lat) float32 100B 75.0 72.5 70.0 67.5 65.0 ... 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 212B 200.0 202.5 205.0 207.5 ... 325.0 327.5 330.0

# %%
ds.data_vars
# Out:
# Data variables:
#     air      (time, lat, lon) float64 31MB ...

# %%
ds.air
# Out:
# <xarray.DataArray 'air' (time: 2920, lat: 25, lon: 53)> Size: 31MB
# [3869000 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 23kB 2013-01-01 ... 2014-12-31T18:00:00
#   * lat      (lat) float32 100B 75.0 72.5 70.0 67.5 65.0 ... 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 212B 200.0 202.5 205.0 207.5 ... 325.0 327.5 330.0
# Attributes:
#     long_name:     4xDaily Air temperature at sigma level 995
#     units:         degK
#     precision:     2
#     GRIB_id:       11
#     GRIB_name:     TMP
#     var_desc:      Air temperature
#     dataset:       NMC Reanalysis
#     level_desc:    Surface
#     statistic:     Individual Obs
#     parent_stat:   Other
#     actual_range:  [185.16 322.1 ]

# %%
ds.air.isel(time=0).plot()

# %%
#create time series
ds.air.isel(lat=10,lon=20).plot()

# %%
ds.air.shape
# Out:
# (2920, 25, 53)

# %%
ds.time
# Out:
# <xarray.DataArray 'time' (time: 2920)> Size: 23kB
# array(['2013-01-01T00:00:00.000000000', '2013-01-01T06:00:00.000000000',
#        '2013-01-01T12:00:00.000000000', ..., '2014-12-31T06:00:00.000000000',
#        '2014-12-31T12:00:00.000000000', '2014-12-31T18:00:00.000000000'],
#       shape=(2920,), dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 23kB 2013-01-01 ... 2014-12-31T18:00:00
# Attributes:
#     standard_name:  time
#     long_name:      Time

# %%
ds.lat
# Out:
# <xarray.DataArray 'lat' (lat: 25)> Size: 100B
# array([75. , 72.5, 70. , 67.5, 65. , 62.5, 60. , 57.5, 55. , 52.5, 50. , 47.5,
#        45. , 42.5, 40. , 37.5, 35. , 32.5, 30. , 27.5, 25. , 22.5, 20. , 17.5,
#        15. ], dtype=float32)
# Coordinates:
#   * lat      (lat) float32 100B 75.0 72.5 70.0 67.5 65.0 ... 22.5 20.0 17.5 15.0
# Attributes:
#     standard_name:  latitude
#     long_name:      Latitude
#     units:          degrees_north
#     axis:           Y

# %%
ds.lon
# Out:
# <xarray.DataArray 'lon' (lon: 53)> Size: 212B
# array([200. , 202.5, 205. , 207.5, 210. , 212.5, 215. , 217.5, 220. , 222.5,
#        225. , 227.5, 230. , 232.5, 235. , 237.5, 240. , 242.5, 245. , 247.5,
#        250. , 252.5, 255. , 257.5, 260. , 262.5, 265. , 267.5, 270. , 272.5,
#        275. , 277.5, 280. , 282.5, 285. , 287.5, 290. , 292.5, 295. , 297.5,
#        300. , 302.5, 305. , 307.5, 310. , 312.5, 315. , 317.5, 320. , 322.5,
#        325. , 327.5, 330. ], dtype=float32)
# Coordinates:
#   * lon      (lon) float32 212B 200.0 202.5 205.0 207.5 ... 325.0 327.5 330.0
# Attributes:
#     standard_name:  longitude
#     long_name:      Longitude
#     units:          degrees_east
#     axis:           X

# %%
clim = ds.air.mean(dim="time")
clim
# Out:
# <xarray.DataArray 'air' (lat: 25, lon: 53)> Size: 11kB
# array([[260.37644178, 260.18305137, 259.88662671, ..., 250.81590068,
#         251.93811644, 253.43804795],
#        [262.73439384, 262.79397603, 262.74933904, ..., 249.75590411,
#         251.58575685, 254.35926027],
#        [264.7687637 , 264.32730822, 264.06169521, ..., 250.60789041,
#         253.58351027, 257.71559932],
#        ...,
#        [297.64986301, 296.95333219, 296.62931507, ..., 296.81092466,
#         296.28796233, 295.81645548],
#        [298.12920205, 297.93700685, 297.47039384, ..., 296.85954795,
#         296.7770274 , 296.44383562],
#        [298.36615068, 298.38573973, 298.11414384, ..., 297.33820548,
#         297.28144521, 297.30510274]], shape=(25, 53))
# Coordinates:
#   * lat      (lat) float32 100B 75.0 72.5 70.0 67.5 65.0 ... 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 212B 200.0 202.5 205.0 207.5 ... 325.0 327.5 330.0
# Attributes:
# ...

# %%
clim.plot(figsize=(10,5))

# %%
ds.air.mean(dim=["lat", "lon"])
# Out:
# <xarray.DataArray 'air' (time: 2920)> Size: 23kB
# array([274.1662717 , 273.52021887, 273.23350943, ..., 272.99996226,
#        273.04449057, 273.41498113], shape=(2920,))
# Coordinates:
#   * time     (time) datetime64[ns] 23kB 2013-01-01 ... 2014-12-31T18:00:00
# Attributes:
#     long_name:     4xDaily Air temperature at sigma level 995
#     units:         degK
#     precision:     2
#     GRIB_id:       11
#     GRIB_name:     TMP
#     var_desc:      Air temperature
#     dataset:       NMC Reanalysis
#     level_desc:    Surface
#     statistic:     Individual Obs
#     parent_stat:   Other
#     actual_range:  [185.16 322.1 ]

# %%
ds.air.mean(dim=["lat", "lon"])
# Out:
# <xarray.DataArray 'air' (time: 2920)> Size: 23kB
# array([274.1662717 , 273.52021887, 273.23350943, ..., 272.99996226,
#        273.04449057, 273.41498113], shape=(2920,))
# Coordinates:
#   * time     (time) datetime64[ns] 23kB 2013-01-01 ... 2014-12-31T18:00:00
# Attributes:
#     long_name:     4xDaily Air temperature at sigma level 995
#     units:         degK
#     precision:     2
#     GRIB_id:       11
#     GRIB_name:     TMP
#     var_desc:      Air temperature
#     dataset:       NMC Reanalysis
#     level_desc:    Surface
#     statistic:     Individual Obs
#     parent_stat:   Other
#     actual_range:  [185.16 322.1 ]

# %%
ts = ds.air.mean(dim=["lat", "lon"])
ts.plot()

# %%
ts = ds.air.mean(dim=["lat","lon"])
ts.plot()

# %%
ts.max()
ts.argmax()
# Out:
# c:\Users\AKHTAR HUSSAIN\anaconda3\envs\climate\Lib\site-packages\xarray\core\dataarray.py:6439: FutureWarning: Behaviour of argmin/argmax with neither dim nor axis argument will change to return a dict of indices of each dimension. To get a single, flat index, please use np.argmin(da.data) or np.argmax(da.data) instead of da.argmin() or da.argmax().
#   result = self.variable.argmax(dim, axis, keep_attrs, skipna)
# <xarray.DataArray 'air' ()> Size: 8B
# array(892)
# Attributes:
#     long_name:     4xDaily Air temperature at sigma level 995
#     units:         degK
#     precision:     2
#     GRIB_id:       11
#     GRIB_name:     TMP
#     var_desc:      Air temperature
#     dataset:       NMC Reanalysis
#     level_desc:    Surface
#     statistic:     Individual Obs
#     parent_stat:   Other
#     actual_range:  [185.16 322.1 ]

# %%
ds.air.attrs
ts.max()
# Out:
# <xarray.DataArray 'air' ()> Size: 8B
# array(292.23443019)
# Attributes:
#     long_name:     4xDaily Air temperature at sigma level 995
#     units:         degK
#     precision:     2
#     GRIB_id:       11
#     GRIB_name:     TMP
#     var_desc:      Air temperature
#     dataset:       NMC Reanalysis
#     level_desc:    Surface
#     statistic:     Individual Obs
#     parent_stat:   Other
#     actual_range:  [185.16 322.1 ]

# %%
#celcius conversion
air_c = ds.air - 273.15
air_c
# Out:
# <xarray.DataArray 'air' (time: 2920, lat: 25, lon: 53)> Size: 31MB
# array([[[-31.95, -30.65, -29.65, ..., -40.35, -37.65, -34.55],
#         [-29.35, -28.65, -28.45, ..., -40.35, -37.85, -33.85],
#         [-23.15, -23.35, -24.26, ..., -39.95, -36.76, -31.45],
#         ...,
#         [ 23.45,  23.05,  23.25, ...,  22.25,  21.95,  21.55],
#         [ 22.75,  23.05,  23.64, ...,  22.75,  22.75,  22.05],
#         [ 23.14,  23.64,  23.95, ...,  23.75,  23.64,  23.45]],
#
#        [[-31.05, -30.45, -30.05, ..., -41.15, -39.55, -37.35],
#         [-29.55, -29.05, -28.95, ..., -42.15, -40.65, -37.45],
#         [-19.95, -20.26, -21.05, ..., -42.35, -39.76, -34.65],
#         ...,
#         [ 23.25,  22.75,  23.05, ...,  22.25,  21.95,  21.64],
#         [ 23.05,  23.55,  23.64, ...,  22.45,  22.35,  21.95],
#         [ 23.14,  24.05,  24.25, ...,  23.25,  23.25,  23.45]],
#
#        [[-30.85, -30.95, -30.85, ..., -38.85, -37.05, -34.45],
# ...

# %%
ts_c=air_c.mean(dim=["lat","lon"])
ts_c.plot()

# %%
ts_c.time[ts_c.argmin()]
# Out:
# c:\Users\AKHTAR HUSSAIN\anaconda3\envs\climate\Lib\site-packages\xarray\core\dataarray.py:6318: FutureWarning: Behaviour of argmin/argmax with neither dim nor axis argument will change to return a dict of indices of each dimension. To get a single, flat index, please use np.argmin(da.data) or np.argmax(da.data) instead of da.argmin() or da.argmax().
#   result = self.variable.argmin(dim, axis, keep_attrs, skipna)
# <xarray.DataArray 'time' ()> Size: 8B
# array('2014-02-12T12:00:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     time     datetime64[ns] 8B 2014-02-12T12:00:00
# Attributes:
#     standard_name:  time
#     long_name:      Time

# %%
ts_c.time[ts_c.argmax()]
# Out:
# c:\Users\AKHTAR HUSSAIN\anaconda3\envs\climate\Lib\site-packages\xarray\core\dataarray.py:6439: FutureWarning: Behaviour of argmin/argmax with neither dim nor axis argument will change to return a dict of indices of each dimension. To get a single, flat index, please use np.argmin(da.data) or np.argmax(da.data) instead of da.argmin() or da.argmax().
#   result = self.variable.argmax(dim, axis, keep_attrs, skipna)
# <xarray.DataArray 'time' ()> Size: 8B
# array('2013-08-12T00:00:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     time     datetime64[ns] 8B 2013-08-12
# Attributes:
#     standard_name:  time
#     long_name:      Time

# %%
air_c.mean(dim="time")
# Out:
# <xarray.DataArray 'air' (lat: 25, lon: 53)> Size: 11kB
# array([[-12.77355822, -12.96694863, -13.26337329, ..., -22.33409932,
#         -21.21188356, -19.71195205],
#        [-10.41560616, -10.35602397, -10.40066096, ..., -23.39409589,
#         -21.56424315, -18.79073973],
#        [ -8.3812363 ,  -8.82269178,  -9.08830479, ..., -22.54210959,
#         -19.56648973, -15.43440068],
#        ...,
#        [ 24.49986301,  23.80333219,  23.47931507, ...,  23.66092466,
#          23.13796233,  22.66645548],
#        [ 24.97920205,  24.78700685,  24.32039384, ...,  23.70954795,
#          23.6270274 ,  23.29383562],
#        [ 25.21615068,  25.23573973,  24.96414384, ...,  24.18820548,
#          24.13144521,  24.15510274]], shape=(25, 53))
# Coordinates:
#   * lat      (lat) float32 100B 75.0 72.5 70.0 67.5 65.0 ... 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 212B 200.0 202.5 205.0 207.5 ... 325.0 327.5 330.0
# Attributes:
# ...

# %%
air_c.isel(time=0)
# Out:
# <xarray.DataArray 'air' (lat: 25, lon: 53)> Size: 11kB
# array([[-31.95, -30.65, -29.65, ..., -40.35, -37.65, -34.55],
#        [-29.35, -28.65, -28.45, ..., -40.35, -37.85, -33.85],
#        [-23.15, -23.35, -24.26, ..., -39.95, -36.76, -31.45],
#        ...,
#        [ 23.45,  23.05,  23.25, ...,  22.25,  21.95,  21.55],
#        [ 22.75,  23.05,  23.64, ...,  22.75,  22.75,  22.05],
#        [ 23.14,  23.64,  23.95, ...,  23.75,  23.64,  23.45]],
#       shape=(25, 53))
# Coordinates:
#   * lat      (lat) float32 100B 75.0 72.5 70.0 67.5 65.0 ... 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 212B 200.0 202.5 205.0 207.5 ... 325.0 327.5 330.0
#     time     datetime64[ns] 8B 2013-01-01
# Attributes:
#     long_name:     4xDaily Air temperature at sigma level 995
#     units:         degK
#     precision:     2
#     GRIB_id:       11
#     GRIB_name:     TMP
#     var_desc:      Air temperature
#     dataset:       NMC Reanalysis
#     level_desc:    Surface
# ...

# %%
air_c.isel(lat=10, lon=20)
# Out:
# <xarray.DataArray 'air' (time: 2920)> Size: 23kB
# array([-3.36, -5.45, -3.25, ..., -6.96, -2.26, -4.76], shape=(2920,))
# Coordinates:
#   * time     (time) datetime64[ns] 23kB 2013-01-01 ... 2014-12-31T18:00:00
#     lat      float32 4B 50.0
#     lon      float32 4B 250.0
# Attributes:
#     long_name:     4xDaily Air temperature at sigma level 995
#     units:         degK
#     precision:     2
#     GRIB_id:       11
#     GRIB_name:     TMP
#     var_desc:      Air temperature
#     dataset:       NMC Reanalysis
#     level_desc:    Surface
#     statistic:     Individual Obs
#     parent_stat:   Other
#     actual_range:  [185.16 322.1 ]

# %%
ts.isel(time=0)
ds.time
# Out:
# <xarray.DataArray 'time' (time: 2920)> Size: 23kB
# array(['2013-01-01T00:00:00.000000000', '2013-01-01T06:00:00.000000000',
#        '2013-01-01T12:00:00.000000000', ..., '2014-12-31T06:00:00.000000000',
#        '2014-12-31T12:00:00.000000000', '2014-12-31T18:00:00.000000000'],
#       shape=(2920,), dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 23kB 2013-01-01 ... 2014-12-31T18:00:00
# Attributes:
#     standard_name:  time
#     long_name:      Time

# %%
ds.air.sel(time="2013-01-01", method="nearest").plot()

# %%
jan = ds.air.sel(
    time=slice("2013-01-01", "2013-01-31")
)

jan
jan_mean = jan.mean(dim="time")

jan_mean.plot()

# %%
jan = ds.air.sel(time=slice("2013-01-01", "2013-01-31"))
feb = ds.air.sel(time= slice("2013-02-01", "2013-02-25"))

jan_mean = jan.mean(dim ="time")
feb_mean = feb.mean(dim="time")

# %%
diff = feb_mean-jan_mean
diff
# Out:
# <xarray.DataArray 'air' (lat: 25, lon: 53)> Size: 11kB
# array([[-4.04657419, -4.31004839, -4.63714194, ..., -0.62035161,
#         -0.38687097, -0.35360645],
#        [-5.59002581, -5.4167    , -5.2899    , ...,  0.54910323,
#          0.48116129,  0.35032258],
#        [-5.53183548, -5.28743871, -5.1933    , ...,  1.71974516,
#          1.36450323,  1.09681935],
#        ...,
#        [-0.43024516, -0.64636774, -0.93834516, ..., -0.3264871 ,
#         -0.34831613, -0.2612871 ],
#        [-0.43171613, -0.61761613, -0.75462581, ..., -0.28274194,
#         -0.24422581, -0.33076452],
#        [-0.57686774, -0.69721613, -0.67782258, ..., -0.42379677,
#         -0.40081935, -0.4718129 ]], shape=(25, 53))
# Coordinates:
#   * lat      (lat) float32 100B 75.0 72.5 70.0 67.5 65.0 ... 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 212B 200.0 202.5 205.0 207.5 ... 325.0 327.5 330.0
# Attributes:
#     long_name:     4xDaily Air temperature at sigma level 995
#     units:         degK
# ...

# %%
diff.plot()
