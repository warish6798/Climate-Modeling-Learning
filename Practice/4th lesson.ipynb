# %%
#imports
import xarray as xr
from pythia_datasets import DATASETS
import matplotlib.pyplot as plt

# %%
#Arithmetic Operations
filepath = DATASETS.fetch("CESM2_sst_data.nc")
ds = xr.open_dataset(filepath)
# Out:
# Downloading file 'CESM2_sst_data.nc' from 'https://github.com/ProjectPythia/pythia-datasets/raw/main/data/CESM2_sst_data.nc' to 'C:\Users\AKHTAR HUSSAIN\AppData\Local\pythia-datasets\pythia-datasets\Cache'.
# c:\Users\AKHTAR HUSSAIN\anaconda3\envs\climate\Lib\site-packages\xarray\conventions.py:205: SerializationWarning: variable 'tos' has multiple fill values {np.float32(1e+20), np.float64(1e+20)} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)

# %%
ds.tos
# Out:
# <xarray.DataArray 'tos' (time: 180, lat: 180, lon: 360)> Size: 47MB
# [11664000 values with dtype=float32]
# Coordinates:
#   * time     (time) object 1kB 2000-01-15 12:00:00 ... 2014-12-15 12:00:00
#   * lat      (lat) float64 1kB -89.5 -88.5 -87.5 -86.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 3kB 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
# Attributes: (12/19)
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean
#     comment:        Model data on the 1x1 grid includes values in all cells f...
#     description:    This may differ from "surface temperature" in regions of ...
#     frequency:      mon
#     id:             tos
#     ...             ...
#     time_label:     time-mean
#     time_title:     Temporal mean
#     title:          Sea Surface Temperature
#     type:           real
#     units:          degC
#     variable_id:    tos

# %%
ds.tos+273.15
# Out:
# <xarray.DataArray 'tos' (time: 180, lat: 180, lon: 360)> Size: 47MB
# array([[[      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         ...,
#         [271.3552 , 271.3553 , 271.3554 , ..., 271.35495, 271.355  ,
#          271.3551 ],
#         [271.36005, 271.36014, 271.36023, ..., 271.35986, 271.35992,
#          271.36   ],
#         [271.36447, 271.36453, 271.3646 , ..., 271.3643 , 271.36435,
#          271.3644 ]],
#
#        [[      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
# ...
#         [271.40677, 271.40674, 271.4067 , ..., 271.40695, 271.4069 ,
#          271.40683],
#         [271.41296, 271.41293, 271.41293, ..., 271.41306, 271.413  ,
#          271.41296],
#         [271.41772, 271.41772, 271.41772, ..., 271.41766, 271.4177 ,
#          271.4177 ]],
#
#        [[      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         ...,
#         [271.39386, 271.39383, 271.3938 , ..., 271.39407, 271.394  ,
#          271.39392],
#         [271.39935, 271.39932, 271.39932, ..., 271.39948, 271.39944,
#          271.39938],
#         [271.40372, 271.40372, 271.40375, ..., 271.4037 , 271.4037 ,
#          271.40372]]], shape=(180, 180, 360), dtype=float32)
# Coordinates:
#   * time     (time) object 1kB 2000-01-15 12:00:00 ... 2014-12-15 12:00:00
#   * lat      (lat) float64 1kB -89.5 -88.5 -87.5 -86.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 3kB 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
# Attributes: (12/19)
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean
#     comment:        Model data on the 1x1 grid includes values in all cells f...
#     description:    This may differ from "surface temperature" in regions of ...
#     frequency:      mon
#     id:             tos
#     ...             ...
#     time_label:     time-mean
#     time_title:     Temporal mean
#     title:          Sea Surface Temperature
#     type:           real
#     units:          degC
#     variable_id:    tos

# %%
ds.tos**2
# Out:
# <xarray.DataArray 'tos' (time: 180, lat: 180, lon: 360)> Size: 47MB
# array([[[      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         ...,
#         [3.2213385, 3.2209656, 3.220537 , ..., 3.2221622, 3.221913 ,
#          3.2216525],
#         [3.203904 , 3.203617 , 3.2032912, ..., 3.2045207, 3.2043478,
#          3.2041442],
#         [3.1881146, 3.1879027, 3.1876712, ..., 3.188714 , 3.1885312,
#          3.1883302]],
#
#        [[      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
# ...
#         [3.0388296, 3.0389647, 3.0390673, ..., 3.038165 , 3.0383828,
#          3.0386322],
#         [3.0173173, 3.0173445, 3.0173297, ..., 3.0169601, 3.0171173,
#          3.0172386],
#         [3.000791 , 3.0007784, 3.0007539, ..., 3.000933 , 3.000896 ,
#          3.0008452]],
#
#        [[      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         ...,
#         [3.0839543, 3.0841148, 3.0842566, ..., 3.0832636, 3.0834875,
#          3.0837412],
#         [3.064733 , 3.0648024, 3.0648358, ..., 3.0642793, 3.0644639,
#          3.0646174],
#         [3.0494578, 3.0494475, 3.0494263, ..., 3.049596 , 3.0495603,
#          3.0495107]]], shape=(180, 180, 360), dtype=float32)
# Coordinates:
#   * time     (time) object 1kB 2000-01-15 12:00:00 ... 2014-12-15 12:00:00
#   * lat      (lat) float64 1kB -89.5 -88.5 -87.5 -86.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 3kB 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
# Attributes: (12/19)
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean
#     comment:        Model data on the 1x1 grid includes values in all cells f...
#     description:    This may differ from "surface temperature" in regions of ...
#     frequency:      mon
#     id:             tos
#     ...             ...
#     time_label:     time-mean
#     time_title:     Temporal mean
#     title:          Sea Surface Temperature
#     type:           real
#     units:          degC
#     variable_id:    tos

# %%
#Aggregation Methods
ds.tos.min(dim="time")
# Out:
# <xarray.DataArray 'tos' (lat: 180, lon: 360)> Size: 259kB
# array([[       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        ...,
#        [-1.8083605, -1.8083031, -1.8082187, ..., -1.8083988, -1.8083944,
#         -1.8083915],
#        [-1.8025414, -1.8024837, -1.8024155, ..., -1.8026428, -1.8026177,
#         -1.8025846],
#        [-1.7984415, -1.7983989, -1.7983514, ..., -1.7985678, -1.7985296,
#         -1.7984871]], shape=(180, 360), dtype=float32)
# Coordinates:
#   * lat      (lat) float64 1kB -89.5 -88.5 -87.5 -86.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 3kB 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
# Attributes: (12/19)
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean
#     comment:        Model data on the 1x1 grid includes values in all cells f...
#     description:    This may differ from "surface temperature" in regions of ...
#     frequency:      mon
#     id:             tos
#     ...             ...
#     time_label:     time-mean
#     time_title:     Temporal mean
#     title:          Sea Surface Temperature
#     type:           real
#     units:          degC
#     variable_id:    tos

# %%
#compute spatial sum
ds.tos.sum(dim=["lat","lon"])
# Out:
# <xarray.DataArray 'tos' (time: 180)> Size: 720B
# array([603767.  , 607702.44, 603976.5 , 599373.5 , 595119.9 , 595716.75,
#        598177.25, 600670.56, 597825.56, 591869.  , 590507.75, 597189.1 ,
#        605954.1 , 609151.  , 606868.94, 602329.9 , 599465.75, 601205.5 ,
#        605144.4 , 608588.44, 604046.9 , 598927.75, 597519.75, 603876.9 ,
#        612424.4 , 615765.1 , 612615.44, 606310.6 , 602034.44, 600784.9 ,
#        602013.5 , 603142.1 , 598850.94, 591917.5 , 589234.56, 596162.5 ,
#        602942.  , 607196.9 , 604928.1 , 601735.7 , 599011.75, 599490.9 ,
#        600801.4 , 602786.8 , 598867.25, 594081.8 , 593736.3 , 598995.6 ,
#        607285.25, 611901.  , 609562.75, 603527.3 , 600215.4 , 601372.56,
#        604144.56, 605376.6 , 601256.25, 595245.1 , 594002.1 , 600490.3 ,
#        611878.6 , 616563.  , 613050.8 , 605733.94, 600808.75, 600898.06,
#        603930.5 , 605644.75, 599917.5 , 592048.1 , 590082.75, 596950.7 ,
#        607702.  , 610844.75, 609509.6 , 603380.9 , 599838.06, 600334.25,
#        604386.7 , 607848.1 , 602155.25, 594949.  , 593815.06, 598365.25,
#        608730.75, 612056.56, 609922.5 , 603077.2 , 600134.1 , 602821.25,
#        606152.75, 610257.8 , 604685.9 , 596858.  , 592894.8 , 599944.94,
#        609764.44, 614610.8 , 611434.75, 605606.4 , 603791.  , 605750.1 ,
#        609250.  , 612935.6 , 609645.  , 601706.4 , 598896.6 , 605349.75,
#        614671.8 , 618686.75, 615895.2 , 609438.25, 605399.5 , 606126.75,
#        607942.25, 609680.4 , 604814.3 , 595841.94, 591908.5 , 595638.7 ,
#        604799.  , 611327.1 , 609765.7 , 603727.6 , 600970.  , 602514.06,
#        606303.6 , 609225.2 , 603724.25, 595944.75, 594477.4 , 597807.4 ,
#        607379.2 , 611808.56, 610113.  , 607196.4 , 604733.1 , 605488.25,
#        610048.4 , 612655.75, 608906.25, 602349.6 , 601754.1 , 609220.4 ,
#        619367.2 , 623783.1 , 619949.75, 613369.1 , 610190.75, 611091.2 ,
#        614213.4 , 615665.06, 611722.1 , 606259.5 , 605970.1 , 611463.4 ,
#        619794.6 , 626036.5 , 623085.4 , 616295.9 , 611886.4 , 611881.9 ,
#        614420.75, 616853.5 , 610375.4 , 603471.5 , 602108.25, 608094.25,
#        617450.7 , 623508.6 , 619830.1 , 612033.25, 608737.25, 610105.25,
#        613692.6 , 616360.5 , 611735.4 , 606512.6 , 604249.4 , 608777.5 ],
#       dtype=float32)
# Coordinates:
#   * time     (time) object 1kB 2000-01-15 12:00:00 ... 2014-12-15 12:00:00
# Attributes: (12/19)
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean
#     comment:        Model data on the 1x1 grid includes values in all cells f...
#     description:    This may differ from "surface temperature" in regions of ...
#     frequency:      mon
#     id:             tos
#     ...             ...
#     time_label:     time-mean
#     time_title:     Temporal mean
#     title:          Sea Surface Temperature
#     type:           real
#     units:          degC
#     variable_id:    tos

# %%
#compute the temporal median
ds.tos.median(dim="time")
# Out:
# <xarray.DataArray 'tos' (lat: 180, lon: 360)> Size: 259kB
# array([[       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        ...,
#        [-1.7648907, -1.7648032, -1.7647004, ..., -1.7650614, -1.7650102,
#         -1.7649589],
#        [-1.7590305, -1.7589546, -1.7588665, ..., -1.7591925, -1.7591486,
#         -1.759095 ],
#        [-1.7536805, -1.753602 , -1.7535168, ..., -1.753901 , -1.753833 ,
#         -1.7537591]], shape=(180, 360), dtype=float32)
# Coordinates:
#   * lat      (lat) float64 1kB -89.5 -88.5 -87.5 -86.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 3kB 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
# Attributes: (12/19)
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean
#     comment:        Model data on the 1x1 grid includes values in all cells f...
#     description:    This may differ from "surface temperature" in regions of ...
#     frequency:      mon
#     id:             tos
#     ...             ...
#     time_label:     time-mean
#     time_title:     Temporal mean
#     title:          Sea Surface Temperature
#     type:           real
#     units:          degC
#     variable_id:    tos

# %%
#compute mean SST
ds.tos.mean()
# Out:
# <xarray.DataArray 'tos' ()> Size: 4B
# array(14.250171, dtype=float32)
# Attributes: (12/19)
#     cell_measures:  area: areacello
#     cell_methods:   area: mean where sea time: mean
#     comment:        Model data on the 1x1 grid includes values in all cells f...
#     description:    This may differ from "surface temperature" in regions of ...
#     frequency:      mon
#     id:             tos
#     ...             ...
#     time_label:     time-mean
#     time_title:     Temporal mean
#     title:          Sea Surface Temperature
#     type:           real
#     units:          degC
#     variable_id:    tos

# %%
ds.tos.mean(dim="time").plot(size=7,vmin=-2,vmax=32,cmap="coolwarm")
